  (3.5, 1): (7, 6),
  (4, 1): (8, 10),
  (4.5, 1): (7, 10),
  (5, 1): (7, 1),
  (5.5, 1): (3, 4),
  (6, 1): (7, 5),
  (6.5, 1): (2, 4),
  (7, 1): (3, 6)}]
main_list5 = [{(0.5, 5): (30, 28),
  (0.6, 5): (23, 27),
  (0.7, 5): (29, 27),
  (0.8, 5): (27, 26),
  (0.9, 5): (29, 23),
  (1.0, 5): (27, 27),
  (1.1, 5): (24, 22),
  (1.2, 5): (30, 27),
  (1.3, 5): (28, 22),
  (1.4, 5): (25, 27)},
 {(0.5, 5): (24, 28),
  (0.6, 5): (29, 23),
  (0.7, 5): (27, 31),
  (0.8, 5): (26, 24),
  (0.9, 5): (33, 26),
  (1.0, 5): (30, 28),
  (1.1, 5): (21, 26),
  (1.2, 5): (27, 24),
  (1.3, 5): (30, 25),
  (1.4, 5): (28, 21)},
 {(0.5, 5): (27, 28),
  (0.6, 5): (26, 30),
  (0.7, 5): (27, 18),
  (0.8, 5): (33, 26),
  (0.9, 5): (25, 28),
  (1.0, 5): (25, 25),
  (1.1, 5): (19, 30),
  (1.2, 5): (22, 20),
  (1.3, 5): (24, 19),
  (1.4, 5): (22, 24)},
 {(0.5, 5): (30, 26),
  (0.6, 5): (24, 25),
  (0.7, 5): (24, 24),
  (0.8, 5): (25, 27),
  (0.9, 5): (31, 26),
  (1.0, 5): (28, 23),
  (1.1, 5): (26, 25),
  (1.2, 5): (22, 24),
  (1.3, 5): (24, 16),
  (1.4, 5): (28, 22)},
 {(0.5, 5): (28, 22),
  (0.6, 5): (26, 26),
  (0.7, 5): (23, 18),
  (0.8, 5): (30, 24),
  (0.9, 5): (26, 26),
  (1.0, 5): (30, 25),
  (1.1, 5): (26, 24),
  (1.2, 5): (23, 25),
  (1.3, 5): (20, 23),
  (1.4, 5): (30, 27)},
 {(0.5, 5): (27, 23),
  (0.6, 5): (24, 25),
  (0.7, 5): (29, 25),
  (0.8, 5): (29, 24),
  (0.9, 5): (22, 25),
  (1.0, 5): (26, 29),
  (1.1, 5): (25, 20),
  (1.2, 5): (23, 26),
  (1.3, 5): (29, 27),
  (1.4, 5): (28, 17)},
 {(0.5, 5): (27, 27),
  (0.6, 5): (29, 24),
  (0.7, 5): (26, 31),
  (0.8, 5): (29, 26),
  (0.9, 5): (25, 27),
  (1.0, 5): (26, 26),
  (1.1, 5): (31, 21),
  (1.2, 5): (23, 28),
  (1.3, 5): (25, 30),
  (1.4, 5): (17, 22)},
 {(0.5, 5): (32, 30),
  (0.6, 5): (31, 31),
  (0.7, 5): (31, 19),
  (0.8, 5): (28, 22),
  (0.9, 5): (28, 25),
  (1.0, 5): (31, 21),
  (1.1, 5): (27, 27),
  (1.2, 5): (26, 19),
  (1.3, 5): (26, 19),
  (1.4, 5): (29, 25)},
 {(0.5, 5): (37, 22),
  (0.6, 5): (28, 28),
  (0.7, 5): (31, 26),
  (0.8, 5): (29, 24),
  (0.9, 5): (30, 29),
  (1.0, 5): (26, 22),
  (1.1, 5): (22, 26),
  (1.2, 5): (25, 22),
  (1.3, 5): (26, 27),
  (1.4, 5): (25, 21)},
 {(0.5, 5): (32, 24),
  (0.6, 5): (32, 32),
  (0.7, 5): (26, 29),
  (0.8, 5): (26, 29),
  (0.9, 5): (26, 27),
  (1.0, 5): (28, 28),
  (1.1, 5): (26, 25),
  (1.2, 5): (23, 26),
  (1.3, 5): (26, 24),
  (1.4, 5): (23, 23)}]
main_list10 = [{(0.25, 10): (40, 32), (0.3, 10): (33, 30), (0.35, 10): (26, 28), (0.4, 10): (30, 29), (0.45, 10): (38, 28), (0.5, 10): (33, 31), (0.55, 10): (34, 27), (0.6, 10): (31, 29), (0.65, 10): (31, 29), (0.7, 10): (27, 29)},
{(0.25, 10): (34, 34), (0.3, 10): (33, 34), (0.35, 10): (31, 27), (0.4, 10): (37, 30), (0.45, 10): (27, 31), (0.5, 10): (36, 30), (0.55, 10): (33, 27), (0.6, 10): (30, 28), (0.65, 10): (32, 30), (0.7, 10): (30, 26)},
{(0.25, 10): (32, 25), (0.3, 10): (35, 23), (0.35, 10): (33, 25), (0.4, 10): (30, 32), (0.45, 10): (28, 30), (0.5, 10): (33, 26), (0.55, 10): (32, 33), (0.6, 10): (36, 26), (0.65, 10): (34, 27), (0.7, 10): (34, 32)},
{(0.25, 10): (35, 35), (0.3, 10): (32, 32), (0.35, 10): (35, 22), (0.4, 10): (28, 35), (0.45, 10): (35, 26), (0.5, 10): (29, 24), (0.55, 10): (28, 30), (0.6, 10): (30, 32), (0.65, 10): (33, 30), (0.7, 10): (32, 26)},
{(0.25, 10): (34, 31),
  (0.3, 10): (33, 31),
  (0.35, 10): (31, 27),
  (0.4, 10): (32, 30),
  (0.45, 10): (29, 32),
  (0.5, 10): (27, 26),
  (0.55, 10): (30, 27),
  (0.6, 10): (32, 27),
  (0.65, 10): (31, 27),
  (0.7, 10): (27, 29)},
 {(0.25, 10): (39, 33),
  (0.3, 10): (34, 31),
  (0.35, 10): (34, 32),
  (0.4, 10): (35, 31),
  (0.45, 10): (27, 29),
  (0.5, 10): (29, 29),
  (0.55, 10): (35, 29),
  (0.6, 10): (28, 28),
  (0.65, 10): (32, 29),
  (0.7, 10): (31, 27)},
 {(0.25, 10): (38, 34),
  (0.3, 10): (30, 28),
  (0.35, 10): (32, 34),
  (0.4, 10): (31, 35),
  (0.45, 10): (35, 30),
  (0.5, 10): (30, 28),
  (0.55, 10): (35, 30),
  (0.6, 10): (37, 33),
  (0.65, 10): (33, 29),
  (0.7, 10): (34, 24)},
 {(0.25, 10): (35, 29),
  (0.3, 10): (35, 30),
  (0.35, 10): (35, 29),
  (0.4, 10): (32, 31),
  (0.45, 10): (34, 32),
  (0.5, 10): (30, 37),
  (0.55, 10): (28, 29),
  (0.6, 10): (28, 28),
  (0.65, 10): (33, 26),
  (0.7, 10): (32, 21)},
 {(0.25, 10): (37, 32),
  (0.3, 10): (30, 34),
  (0.35, 10): (37, 32),
  (0.4, 10): (38, 29),
  (0.45, 10): (27, 30),
  (0.5, 10): (27, 26),
 {(0.5, 5): (13, 243),
  (0.6, 5): (20, 295),
  (0.7, 5): (19, 269),
  (0.8, 5): (16, 221),
  (0.9, 5): (19, 282),
  (1.0, 5): (18, 242),
  (1.1, 5): (18, 228),
  (1.2, 5): (15, 222),
  (1.3, 5): (19, 222),
  (1.4, 5): (15, 215)},
 {(0.5, 5): (13, 289),
  (0.6, 5): (14, 278),
  (0.7, 5): (10, 265),
  (0.8, 5): (16, 227),
  (0.9, 5): (15, 249),
  (1.0, 5): (23, 236),
  (1.1, 5): (18, 233),
  (1.2, 5): (16, 229),
  (1.3, 5): (12, 202),
  (1.4, 5): (12, 211)}]
main_list10_same = [{(0.25, 10): (24, 288), (0.3, 10): (16, 275), (0.35, 10): (17, 308), (0.4, 10): (23, 269), (0.45, 10): (23, 287), (0.5, 10): (25, 257), (0.55, 10): (12, 287), (0.6, 10): (19, 231), (0.65, 10): (22, 233), (0.7, 10): (23, 230)},
{(0.25, 10): (21, 278), (0.3, 10): (23, 275), (0.35, 10): (22, 303), (0.4, 10): (14, 285), (0.45, 10): (17, 257), (0.5, 10): (17, 262), (0.55, 10): (15, 256), (0.6, 10): (21, 265), (0.65, 10): (24, 231), (0.7, 10): (23, 235)},
{(0.25, 10): (18, 305),
  (0.3, 10): (22, 287),
  (0.35, 10): (19, 289),
  (0.4, 10): (18, 286),
  (0.45, 10): (22, 267),
  (0.5, 10): (15, 263),
  (0.55, 10): (19, 277),
  (0.6, 10): (23, 237),
  (0.65, 10): (16, 231),
  (0.7, 10): (24, 235)},
 {(0.25, 10): (18, 301),
  (0.3, 10): (15, 289),
  (0.35, 10): (24, 306),
  (0.4, 10): (18, 273),
  (0.45, 10): (21, 270),
  (0.5, 10): (20, 297),
  (0.55, 10): (21, 270),
  (0.6, 10): (14, 261),
  (0.65, 10): (16, 231),
  (0.7, 10): (16, 228)},
 {(0.25, 10): (23, 286),
  (0.3, 10): (21, 291),
  (0.35, 10): (21, 290),
  (0.4, 10): (15, 259),
  (0.45, 10): (23, 271),
  (0.5, 10): (17, 288),
  (0.55, 10): (21, 277),
  (0.6, 10): (22, 247),
  (0.65, 10): (19, 256),
  (0.7, 10): (20, 217)},
 {(0.25, 10): (18, 312),
  (0.3, 10): (15, 286),
  (0.35, 10): (19, 285),
  (0.4, 10): (18, 275),
  (0.45, 10): (20, 265),
  (0.5, 10): (15, 276),
  (0.55, 10): (18, 273),
  (0.6, 10): (19, 260),
  (0.65, 10): (15, 243),
  (0.7, 10): (19, 253)},
 {(0.25, 10): (20, 279),
  (0.3, 10): (18, 314),
  (0.35, 10): (14, 283),
  (0.4, 10): (18, 289),
  (0.45, 10): (20, 277),
  (0.5, 10): (15, 271),
  (0.55, 10): (22, 257),
  (0.6, 10): (18, 251),
  (0.65, 10): (18, 243),
  (0.7, 10): (19, 222)},
 {(0.25, 10): (17, 300),
  (0.3, 10): (21, 259),
  (0.35, 10): (23, 294),
  (0.4, 10): (18, 280),
  (0.45, 10): (19, 275),
  (0.5, 10): (14, 287),
  (0.55, 10): (16, 262),
  (0.6, 5): (224, 114),
  (0.7, 5): (238, 104),
  (0.8, 5): (233, 112),
  (0.9, 5): (214, 105),
  (1.0, 5): (227, 114),
  (1.1, 5): (235, 116),
  (1.2, 5): (245, 111),
  (1.3, 5): (235, 114),
  (1.4, 5): (225, 113)},
 {(0.5, 5): (239, 123),
  (0.6, 5): (234, 108),
  (0.7, 5): (232, 115),
  (0.8, 5): (238, 118),
  (0.9, 5): (235, 111),
  (1.0, 5): (223, 107),
  (1.1, 5): (224, 97),
  (1.2, 5): (237, 105),
  (1.3, 5): (219, 108),
  (1.4, 5): (215, 103)},
 {(0.5, 5): (219, 112),
  (0.6, 5): (230, 108),
  (0.7, 5): (227, 113),
  (0.8, 5): (235, 113),
  (0.9, 5): (224, 106),
  (1.0, 5): (235, 112),
  (1.1, 5): (222, 112),
  (1.2, 5): (233, 108),
  (1.3, 5): (240, 118),
  (1.4, 5): (224, 112)}]
vru_diff10 = [{(0.25, 10): (257, 123),
  (0.3, 10): (253, 121),
  (0.35, 10): (266, 125),
  (0.4, 10): (267, 117),
  (0.45, 10): (261, 130),
  (0.5, 10): (257, 122),
  (0.55, 10): (257, 128),
  (0.6, 10): (255, 114),
  (0.65, 10): (257, 128),
  (0.7, 10): (249, 120)},
 {(0.25, 10): (255, 125),
  (0.3, 10): (257, 116),
  (0.35, 10): (263, 122),
  (0.4, 10): (248, 105),
  (0.45, 10): (248, 117),
  (0.5, 10): (258, 126),
  (0.55, 10): (246, 107),
  (0.6, 10): (263, 123),
  (0.65, 10): (267, 119),
  (0.7, 10): (249, 121)},
 {(0.25, 10): (247, 126),
  (0.3, 10): (266, 119),
  (0.35, 10): (251, 122),
  (0.4, 10): (253, 125),
  (0.45, 10): (254, 127),
  (0.5, 10): (266, 118),
  (0.55, 10): (255, 120),
  (0.6, 10): (261, 124),
  (0.65, 10): (241, 128),
  (0.7, 10): (259, 129)},
 {(0.25, 10): (252, 118),
  (0.3, 10): (255, 114),
  (0.35, 10): (256, 113),
  (0.4, 10): (268, 117),
  (0.45, 10): (251, 126),
  (0.5, 10): (242, 127),
  (0.55, 10): (250, 112),
  (0.6, 10): (251, 119),
  (0.65, 10): (250, 116),
  (0.7, 10): (262, 122)},
 {(0.25, 10): (254, 116),
  (0.3, 10): (256, 127),
  (0.35, 10): (252, 124),
  (0.4, 10): (254, 116),
  (0.45, 10): (247, 126),
  (0.5, 10): (267, 119),
  (0.55, 10): (262, 120),
  (0.6, 10): (252, 116),
  (0.65, 10): (259, 122),
  (0.7, 10): (261, 112)},
 {(0.25, 10): (256, 113),
  (0.3, 10): (270, 128),
  (0.35, 10): (259, 126),
  (0.4, 10): (250, 128),
  (0.45, 10): (256, 122),
  (0.5, 10): (243, 124),
  (0.55, 10): (260, 115),
  (0.6, 10): (249, 117),
  (0.65, 10): (258, 124),
  (0.7, 10): (258, 124)},
 {(0.25, 10): (249, 122),
  (0.3, 10): (250, 121),
  (0.35, 10): (263, 122),
  (0.4, 10): (250, 116),
  (0.45, 10): (258, 112),
  (0.7, 10): (130, 67)},
 {(0.25, 10): (167, 84),
  (0.3, 10): (154, 84),
  (0.35, 10): (148, 67),
  (0.4, 10): (146, 60),
  (0.45, 10): (161, 70),
  (0.5, 10): (141, 69),
  (0.55, 10): (173, 72),
  (0.6, 10): (152, 72),
  (0.65, 10): (149, 71),
  (0.7, 10): (155, 69)},
 {(0.25, 10): (144, 76),
  (0.3, 10): (154, 77),
  (0.35, 10): (157, 75),
  (0.4, 10): (145, 67),
  (0.45, 10): (150, 67),
  (0.5, 10): (133, 70),
  (0.55, 10): (147, 70),
  (0.6, 10): (143, 72),
  (0.65, 10): (158, 72),
  (0.7, 10): (150, 65)},
 {(0.25, 10): (160, 76),
  (0.3, 10): (151, 66),
  (0.35, 10): (169, 62),
  (0.4, 10): (154, 75),
  (0.45, 10): (149, 68),
  (0.5, 10): (146, 67),
  (0.55, 10): (161, 68),
  (0.6, 10): (142, 63),
  (0.65, 10): (139, 74),
  (0.7, 10): (146, 80)},
 {(0.25, 10): (151, 71),
  (0.3, 10): (147, 63),
  (0.35, 10): (150, 70),
  (0.4, 10): (153, 65),
  (0.45, 10): (135, 81),
  (0.5, 10): (153, 72),
  (0.55, 10): (154, 72),
  (0.6, 10): (135, 62),
  (0.65, 10): (157, 62),
  (0.7, 10): (149, 61)}]

# %%
def TPR(tp, fn):
    frac = tp/(tp+fn)
    return 100*frac

# %%
def FPR(fp, tn):
    frac = fp/(fp+tn)
    return 100*frac

# %%
def tpr_list_generator(group_list):
    result_list = []
    for elt in group_list:
        temp_list = []
        for e in elt:
            temp_list.append(TPR(e,43-e))
        result_list.append(temp_list)
    return result_list

# %%
def tpr_list_generator_vru(group_list):
    result_list = []
    for elt in group_list:
        temp_list = []
        for e in elt:
            temp_list.append(TPR(e,311-e))
        result_list.append(temp_list)
    return result_list

# %%
def fpr_list_generator_vru(group_list):
    result_list = []
    for elt in group_list:
        temp_list = []
        for e in elt:
            temp_list.append(FPR(e,460-311-e))
        result_list.append(temp_list)
    return result_list

# %%
def fpr_list_generator(group_list):
    result_list = []
    for elt in group_list:
        temp_list = []
        for e in elt:
            temp_list.append(FPR(e,720-43-e))
        result_list.append(temp_list)
    return result_list

# %%
group_list_tpr5 = []
group_list_fpr5 = []
group_list_tpr10 = []
group_list_fpr10 = []
group_list_tpr1 = []
group_list_fpr1 = []
group_list_tpr5_same = []
group_list_fpr5_same = []
group_list_tpr10_same = []
group_list_fpr10_same = []
group_list_tpr1_same = []
group_list_fpr1_same = []
vru_diff1_tpr = []
vru_diff5_tpr = []
vru_diff10_tpr = []
vru_diff1_fpr = []
vru_diff5_fpr = []
vru_diff10_fpr = []
vru_same10_tpr = []
vru_same10_fpr = []
eps1 = [2.5,3,3.5,4,4.5,5,5.5,6,6.5,7]
eps5 = []
eps10 = []
for eps in eps1:
    eps5.append(eps/5)
    eps10.append(eps/10)
for elt in eps1:
    temp_list1 = []
    temp_list2 = []
    for e in main_lis1:
        temp_list1.append(e[(elt,1)][0])
        temp_list2.append(e[(elt,1)][1])
    group_list_tpr1.append(temp_list1)
    group_list_fpr1.append(temp_list2)
    temp_list1 = []
    temp_list2 = []
    for e in main_list_same1:
        temp_list1.append(e[(elt,1)][0])
        temp_list2.append(e[(elt,1)][1])
    group_list_tpr1_same.append(temp_list1)
    group_list_fpr1_same.append(temp_list2)
    temp_list1 = []
    temp_list2 = []
    for e in vru_diff1:
        temp_list1.append(e[(elt,1)][0])
        temp_list2.append(e[(elt,1)][1])
    vru_diff1_tpr.append(temp_list1)
    vru_diff1_fpr.append(temp_list2)
    
for elt in eps5:
    temp_list1 = []
    temp_list2 = []
    for e in main_list5:
        temp_list1.append(e[(elt,5)][0])
        temp_list2.append(e[(elt,5)][1])
    group_list_tpr5.append(temp_list1)
    group_list_fpr5.append(temp_list2)
    temp_list1 = []
    temp_list2 = []
    for e in main_list5_same:
        temp_list1.append(e[(elt,5)][0])
        temp_list2.append(e[(elt,5)][1])
    group_list_tpr5_same.append(temp_list1)
    group_list_fpr5_same.append(temp_list2)
    temp_list1 = []
    temp_list2 = []
    for e in vru_diff5:
        temp_list1.append(e[(elt,5)][0])
        temp_list2.append(e[(elt,5)][1])
    vru_diff5_tpr.append(temp_list1)
    vru_diff5_fpr.append(temp_list2)


for elt in eps10:
    temp_list1 = []
    temp_list2 = []
    for e in main_list10:
        temp_list1.append(e[(elt,10)][0])
        temp_list2.append(e[(elt,10)][1])
    group_list_tpr10.append(temp_list1)
    group_list_fpr10.append(temp_list2)
    temp_list1 = []
    temp_list2 = []
    for e in main_list10_same:
        temp_list1.append(e[(elt,10)][0])
        temp_list2.append(e[(elt,10)][1])
    group_list_tpr10_same.append(temp_list1)
    group_list_fpr10_same.append(temp_list2)
    temp_list1 = []
    temp_list2 = []
    for e in vru_diff10:
        temp_list1.append(e[(elt,10)][0])
        temp_list2.append(e[(elt,10)][1])
    vru_diff10_tpr.append(temp_list1)
    vru_diff10_fpr.append(temp_list2)
    temp_list1 = []
    temp_list2 = []
    for e in vru_same10:
        temp_list1.append(e[(elt,10)][0])
        temp_list2.append(e[(elt,10)][1])
    vru_same10_tpr.append(temp_list1)
    vru_same10_fpr.append(temp_list2)
print(vru_diff1_tpr)
group_list_tpr1 = tpr_list_generator(group_list_tpr1)
group_list_tpr5 = tpr_list_generator(group_list_tpr5)
group_list_tpr10 = tpr_list_generator(group_list_tpr10)
group_list_fpr1 = fpr_list_generator(group_list_fpr1)
group_list_fpr5 = fpr_list_generator(group_list_fpr5)
group_list_fpr10 = fpr_list_generator(group_list_fpr10)
group_list_tpr5_same = tpr_list_generator(group_list_tpr5_same)
group_list_fpr5_same = fpr_list_generator(group_list_fpr5_same)
group_list_tpr10_same = tpr_list_generator(group_list_tpr10_same)
group_list_fpr10_same = fpr_list_generator(group_list_fpr10_same)
grpup_list_tpr1_same = tpr_list_generator(group_list_tpr1_same)
group_list_fpr1_same = fpr_list_generator(group_list_fpr1_same)
vru_diff1_tpr = tpr_list_generator_vru(vru_diff1_tpr)
vru_diff5_tpr = tpr_list_generator_vru(vru_diff5_tpr)
vru_diff10_tpr = tpr_list_generator_vru(vru_diff10_tpr)
vru_diff1_fpr = fpr_list_generator_vru(vru_diff1_fpr)
vru_diff5_fpr = fpr_list_generator_vru(vru_diff5_fpr)
vru_diff10_fpr = fpr_list_generator_vru(vru_diff10_fpr)
vru_same10_tpr = tpr_list_generator_vru(vru_same10_tpr)
vru_same10_fpr = fpr_list_generator_vru(vru_same10_fpr)
# Out:
# [[153, 154, 154, 143, 159, 151, 149, 149, 141, 153], [144, 137, 145, 135, 141, 168, 141, 137, 146, 139], [133, 154, 162, 141, 145, 134, 132, 150, 160, 135], [142, 149, 140, 159, 162, 162, 138, 152, 147, 160], [152, 145, 142, 155, 138, 133, 163, 140, 134, 134], [138, 121, 138, 140, 132, 161, 149, 139, 151, 107], [144, 147, 140, 153, 127, 144, 142, 143, 141, 155], [139, 131, 133, 143, 119, 134, 144, 124, 145, 144], [145, 117, 128, 146, 124, 122, 124, 135, 126, 123], [131, 120, 151, 130, 147, 137, 118, 119, 140, 108]]

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')
bpl = plt.boxplot(group_list_tpr1, positions=np.array(range(len(group_list_tpr1)))*2.0-0.4, sym='', widths = 0.3)
bpm = plt.boxplot(group_list_tpr5, positions=np.array(range(len(group_list_tpr5)))*2.0, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_tpr10, positions=np.array(range(len(group_list_tpr10)))*2.0+0.4, sym='', widths = 0.3)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpm, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Run Number = 1 with different set')
plt.plot([], c='#2C7BB6', label='Run Number = 5 with different set')
plt.plot([], c='#31A354', label='Run Number = 10 with different set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,100)
plt.tight_layout()
plt.xlabel("Combined_Epsilon")
plt.ylabel("TPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')
bpl = plt.boxplot(group_list_fpr1, positions=np.array(range(len(group_list_fpr1)))*2.0-0.4, sym='', widths = 0.3)
bpm = plt.boxplot(group_list_fpr5, positions=np.array(range(len(group_list_fpr5)))*2.0, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_fpr10, positions=np.array(range(len(group_list_fpr10)))*2.0+0.4, sym='', widths = 0.3)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpm, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Run Number = 1 with different set')
plt.plot([], c='#2C7BB6', label='Run Number = 5 with different set')
plt.plot([], c='#31A354', label='Run Number = 10 with different set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,6)
plt.tight_layout()
plt.xlabel("Combined_Epsilon")
plt.ylabel("FPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')
bpl = plt.boxplot(group_list_tpr1_same, positions=np.array(range(len(group_list_tpr1_same)))*2.0-0.4, sym='', widths = 0.3)
bpm = plt.boxplot(group_list_tpr5, positions=np.array(range(len(group_list_tpr5)))*2.0, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_tpr10, positions=np.array(range(len(group_list_tpr10)))*2.0+0.4, sym='', widths = 0.3)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpm, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 5')
plt.plot([], c='#31A354', label='Run Number = 10')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,100)
plt.tight_layout()
plt.xlabel("Combined_Epsilon")
plt.ylabel("TPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')
bpl = plt.boxplot(group_list_fpr1_same, positions=np.array(range(len(group_list_fpr1_same)))*2.0-0.4, sym='', widths = 0.3)
bpm = plt.boxplot(group_list_fpr5, positions=np.array(range(len(group_list_fpr5)))*2.0, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_fpr10, positions=np.array(range(len(group_list_fpr10)))*2.0+0.4, sym='', widths = 0.3)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpm, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 5')
plt.plot([], c='#31A354', label='Run Number = 10')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,35)
plt.tight_layout()
plt.xlabel("Combined_Epsilon")
plt.ylabel("FPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')

bpl = plt.boxplot(group_list_fpr1_same, positions=np.array(range(len(group_list_fpr1_same)))*2.0-0.4, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_fpr1, positions=np.array(range(len(group_list_fpr1)))*2.0+0.4, sym='', widths = 0.3)
#set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpl, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
#plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 1 With Same set')
plt.plot([], c='#31A354', label='Run Number = 1 With diff set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,35)
plt.tight_layout()
plt.xlabel("Epsilon")
plt.ylabel("FPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')

bpl = plt.boxplot(group_list_tpr1_same, positions=np.array(range(len(group_list_tpr1_same)))*2.0-0.4, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_tpr1, positions=np.array(range(len(group_list_tpr1)))*2.0+0.4, sym='', widths = 0.3)
#set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpl, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
#plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 1 with same set')
plt.plot([], c='#31A354', label='Run Number = 1 with different set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,50)
plt.tight_layout()
plt.xlabel("Epsilon")
plt.ylabel("TPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')

bpl = plt.boxplot(group_list_tpr5_same, positions=np.array(range(len(group_list_tpr5_same)))*2.0-0.4, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_tpr10_same, positions=np.array(range(len(group_list_tpr10_same)))*2.0+0.4, sym='', widths = 0.3)
#set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpl, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
#plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 5 with same set')
plt.plot([], c='#31A354', label='Run Number = 10 with same set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(10,80)
plt.tight_layout()
plt.xlabel("Combined Epsilon")
plt.ylabel("TPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')

bpl = plt.boxplot(group_list_fpr5_same, positions=np.array(range(len(group_list_fpr5_same)))*2.0-0.4, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_fpr10_same, positions=np.array(range(len(group_list_fpr10_same)))*2.0+0.4, sym='', widths = 0.3)
#set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpl, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
#plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 5 with same set')
plt.plot([], c='#31A354', label='Run Number = 10 with same set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(20,50)
plt.tight_layout()
plt.xlabel("Combined Epsilon")
plt.ylabel("FPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')

bpl = plt.boxplot(group_list_tpr5_same, positions=np.array(range(len(group_list_tpr5_same)))*2.0-0.4, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_tpr5, positions=np.array(range(len(group_list_tpr5)))*2.0+0.4, sym='', widths = 0.3)
#set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpl, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
#plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 5 with same set')
plt.plot([], c='#31A354', label='Run Number = 5 with different set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,100)
plt.tight_layout()
plt.xlabel("Epsilon")
plt.ylabel("TPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')

bpl = plt.boxplot(group_list_fpr5_same, positions=np.array(range(len(group_list_fpr5_same)))*2.0-0.4, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_fpr5, positions=np.array(range(len(group_list_fpr5)))*2.0+0.4, sym='', widths = 0.3)
#set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpl, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
#plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 5 With Same set')
plt.plot([], c='#31A354', label='Run Number = 5 With diff set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,50)
plt.tight_layout()
plt.xlabel("Epsilon")
plt.ylabel("FPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')

bpl = plt.boxplot(group_list_tpr10_same, positions=np.array(range(len(group_list_tpr10_same)))*2.0-0.4, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_tpr10, positions=np.array(range(len(group_list_tpr10)))*2.0+0.4, sym='', widths = 0.3)
#set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpl, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
#plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 10 with same set')
plt.plot([], c='#31A354', label='Run Number = 10 with different set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,100)
plt.tight_layout()
plt.xlabel("Epsilon")
plt.ylabel("TPR")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')

bpl = plt.boxplot(group_list_fpr10_same, positions=np.array(range(len(group_list_fpr10_same)))*2.0-0.4, sym='', widths = 0.3)
bpr = plt.boxplot(group_list_fpr10, positions=np.array(range(len(group_list_fpr10)))*2.0+0.4, sym='', widths = 0.3)
#set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpl, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
#plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 10 With Same set')
plt.plot([], c='#31A354', label='Run Number = 10 With diff set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,50)
plt.tight_layout()
plt.xlabel("Epsilon")
plt.ylabel("FPR")
plt.savefig('boxcompare.png')

# %%
vru_diff10_tpr
# Out:
# [[], [], [], [], [], [], [], [], [], []]

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')
bpl = plt.boxplot(vru_diff1_tpr, positions=np.array(range(len(vru_diff1_tpr)))*2.0-0.4, sym='', widths = 0.3)
bpm = plt.boxplot(vru_diff5_tpr, positions=np.array(range(len(vru_diff5_tpr)))*2.0, sym='', widths = 0.3)
bpr = plt.boxplot(vru_diff10_tpr, positions=np.array(range(len(vru_diff10_tpr)))*2.0+0.4, sym='', widths = 0.3)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpm, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Run Number = 1 with different set')
plt.plot([], c='#2C7BB6', label='Run Number = 5 with different set')
plt.plot([], c='#31A354', label='Run Number = 10 with different set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,100)
plt.tight_layout()
plt.xlabel("Combined_Epsilon")
plt.ylabel("TPR")
plt.title("VRU Dataset")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')
bpl = plt.boxplot(vru_diff1_fpr, positions=np.array(range(len(vru_diff1_fpr)))*2.0-0.4, sym='', widths = 0.3)
bpm = plt.boxplot(vru_diff5_fpr, positions=np.array(range(len(vru_diff5_fpr)))*2.0, sym='', widths = 0.3)
bpr = plt.boxplot(vru_diff10_fpr, positions=np.array(range(len(vru_diff10_fpr)))*2.0+0.4, sym='', widths = 0.3)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpm, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Run Number = 1 with different set')
plt.plot([], c='#2C7BB6', label='Run Number = 5 with different set')
plt.plot([], c='#31A354', label='Run Number = 10 with different set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(0,100)
plt.tight_layout()
plt.xlabel("Combined_Epsilon")
plt.ylabel("FPR")
plt.title("VRU Dataset")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')

bpl = plt.boxplot(vru_same10_tpr, positions=np.array(range(len(vru_same10_tpr)))*2.0-0.4, sym='', widths = 0.3)
bpr = plt.boxplot(vru_diff10_tpr, positions=np.array(range(len(vru_diff10_tpr)))*2.0+0.4, sym='', widths = 0.3)
#set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpl, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
#plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 10 with same set')
plt.plot([], c='#31A354', label='Run Number = 10 with different set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(40,100)
plt.tight_layout()
plt.xlabel("Epsilon")
plt.ylabel("TPR")
plt.title("VRU Dataset")
plt.savefig('boxcompare.png')

# %%
import matplotlib.pyplot as plt
import numpy as np


ticks = eps1

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

fig = plt.figure()
fig.patch.set_facecolor('xkcd:white')

bpl = plt.boxplot(vru_same10_fpr, positions=np.array(range(len(vru_same10_fpr)))*2.0-0.4, sym='', widths = 0.3)
bpr = plt.boxplot(vru_diff10_fpr, positions=np.array(range(len(vru_diff10_fpr)))*2.0+0.4, sym='', widths = 0.3)
#set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpl, '#2C7BB6')
set_box_color(bpr, '#31A354')

# draw temporary red and blue lines and use them to create a legend
#plt.plot([], c='#D7191C', label='Run Number = 1')
plt.plot([], c='#2C7BB6', label='Run Number = 10 with same set')
plt.plot([], c='#31A354', label='Run Number = 10 with different set')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-3, len(ticks)*2)
plt.ylim(30,100)
plt.tight_layout()
plt.xlabel("Epsilon")
plt.ylabel("FPR")
plt.title("VRU Dataset")
plt.savefig('boxcompare.png')
